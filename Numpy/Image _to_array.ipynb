# %% [raw]
# ## Image to Array

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
pip install pillow    # No need to install it everytime
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image  # Pthon Image Library

# %%
image = Image.open(r"C:\Users\raymo\Downloads\image.jpg")

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300>

# %%
type(image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
image_arr = np.asarray(image)  # Convert imag eto array
image_arr
# Out:
# array([[[39,  0,  1],
#         [39,  0,  1],
#         [39,  0,  1],
#         ...,
#         [39,  1,  0],
#         [39,  1,  0],
#         [39,  1,  0]],
#
#        [[39,  0,  1],
#         [39,  0,  1],
#         [39,  0,  1],
#         ...,
#         [38,  0,  0],
#         [38,  0,  0],
#         [38,  0,  0]],
#
#        [[39,  0,  1],
#         [39,  0,  1],
#         [39,  0,  1],
#         ...,
#         [38,  0,  0],
#         [38,  0,  0],
#         [38,  0,  0]],
#
#        ...,
#
#        [[35,  1,  0],
#         [35,  1,  0],
#         [35,  1,  0],
#         ...,
#         [42,  0,  1],
#         [42,  0,  1],
#         [42,  0,  1]],
#
#        [[33,  2,  0],
#         [33,  2,  0],
#         [33,  2,  0],
#         ...,
#         [42,  0,  1],
#         [42,  0,  1],
#         [42,  0,  1]],
#
#        [[33,  2,  0],
#         [33,  2,  0],
#         [33,  2,  0],
#         ...,
#         [42,  0,  1],
#         [42,  0,  1],
# ...

# %%
image_arr.shape  # height , width , 3D channel
# Out:
# (300, 300, 3)

# %%
plt.imshow(image_arr)  # show the image array
plt.show()
