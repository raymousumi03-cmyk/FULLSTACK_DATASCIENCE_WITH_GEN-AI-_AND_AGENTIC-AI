# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# #Storing and printing value

# %%
age=5  #int variable
print(age)
# Out:
# 5

# %%
mark=5.5  #float variable
print(mark)
# Out:
# 5.5

# %%
name="Mousumi" #string variable
print(name)
# Out:
# Mousumi

# %%
active=True  #boolean variable
print(active)
# Out:
# True

# %% [markdown]
# #using variable in expression

# %%
length=10
breadth=5
area=length*breadth
print(area)
# Out:
# 50

# %% [markdown]
# #changing the value of variable

# %%
marks=50 #initial value
print(marks)
# Out:
# 50

# %%
marks=90 #changing the value of marks
print(marks)
# Out:
# 90

# %%
first_name = 'Mousumi'
last_name = 'Ray'
country = 'India'
city = 'Odisha'
age = 23
is_married = False
skills = ['HTML', 'CSS', 'JS', 'React', 'Python']
person_info = {
    'firstname':'Adarsha', 
    'lastname':'Dash', 
    'country':'India',
    'city':'Banglore'
    }

# Printing the values stored in the variables

print('First name:', first_name)
print('First name length:', len(first_name))
print('Last name: ', last_name)
print('Last name length: ', len(last_name))
print('Country: ', country)
print('City: ', city)
print('Age: ', age)
print('Married: ', is_married)
print('Skills: ', skills)
print('Person information: ', person_info)
# Out:
# First name: Mousumi
# First name length: 7
# Last name:  Ray
# Last name length:  3
# Country:  India
# City:  Odisha
# Age:  23
# Married:  False
# Skills:  ['HTML', 'CSS', 'JS', 'React', 'Python']
# Person information:  {'firstname': 'Adarsha', 'lastname': 'Dash', 'country': 'India', 'city': 'Banglore'}

# %%
# Declaring multiple variables in one line

first_name, last_name, country, age, is_married = 'Mousumi', 'Ray', 'India', 23, False

print(first_name, last_name, country, age, is_married)
print('First name:', first_name)
print('Last name: ', last_name)
print('Country: ', country)
print('Age: ', age)
print('Married: ', is_married)
# Out:
# Mousumi Ray India 23 False
# First name: Mousumi
# Last name:  Ray
# Country:  India
# Age:  23
# Married:  False

# %% [markdown]
# #Datatypes

# %%
i=5
print(i)
print(type(i))
print(id(i))
# Out:
# 5
# <class 'int'>
# 140722754397224

# %%
i=5.6
print(i)
print(type(i))
print(id(i))
# Out:
# 5.6
# <class 'float'>
# 2407079498640

# %%
i='Mousumi'
print(i)
print(type(i))
print(id(i))
# Out:
# Mousumi
# <class 'str'>
# 2407079775136

# %%
i="Mousumi 
ray"
print(i)
print(type(i))
print(id(i))
# Out:
#   Cell In[15], line 1
#     i="Mousumi
#       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
i="Mousumi ray"
print(i)
print(type(i))
print(id(i))
# Out:
# Mousumi ray
# <class 'str'>
# 2407079983536

# %%
i='''Mousumi
ray'''
print(i)
print(type(i))
print(id(i))
# Out:
# Mousumi
# ray
# <class 'str'>
# 2407080007216

# %%
i=true
print(i)
print(type(i))
print(id(i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 i=true
#       2 print(i)
#       3 print(type(i))
#
# NameError: name 'true' is not defined

# %%
j=True
print(j)
print(type(j))
print(id(j))
# Out:
# True
# <class 'bool'>
# 140722753485280

# %%
j=False
print(j)
print(type(j))
print(id(j))
# Out:
# False
# <class 'bool'>
# 140722753485312

# %%
True * False
# Out:
# 0

# %%
False*True
# Out:
# 0

# %%
False/True
# Out:
# 0.0

# %%
False//True
# Out:
# 0

# %%
c = 10 + 20j 
print(c)
print(type(c))
# Out:
# (10+20j)
# <class 'complex'>

# %%
c1 = 20 + 20j 
print(c1)
print(type(c1))
# Out:
# (20+20j)
# <class 'complex'>

# %%
c+c1
# Out:
# (30+40j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %% [markdown]
# #String Indexing

# %% [markdown]
# #FORWARD INDEXING

# %%
a="HELLO EVERYONE"
a
# Out:
# 'HELLO EVERYONE'

# %%
a[9]
# Out:
# 'R'

# %%
a[0]
# Out:
# 'H'

# %%
a[18]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 a[18]
#
# IndexError: string index out of range

# %%
a[13]
# Out:
# 'E'

# %% [markdown]
# #BACKWARD INDEXING

# %%
a[-1]
# Out:
# 'E'

# %%
a[-12]
# Out:
# 'L'

# %%
a[-6]
# Out:
# 'E'

# %%
a[-16]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 a[-16]
#
# IndexError: string index out of range

# %% [markdown]
# #Slicing

# %% [markdown]
# #FORWARD SLICING

# %%
b="HELLO WELCOME TO NARESH IT"
b
# Out:
# 'HELLO WELCOME TO NARESH IT'

# %%
b[:]
# Out:
# 'HELLO WELCOME TO NARESH IT'

# %%
b[1:9]
# Out:
# 'ELLO WEL'

# %%
b[10:18]
# Out:
# 'OME TO N'

# %%
b[:20]
# Out:
# 'HELLO WELCOME TO NAR'

# %%
b[20:]
# Out:
# 'ESH IT'

# %%
b[:40]
# Out:
# 'HELLO WELCOME TO NARESH IT'

# %%
b[16:90]
# Out:
# ' NARESH IT'

# %% [markdown]
# #Backward slicing

# %%
b[:]
# Out:
# 'HELLO WELCOME TO NARESH IT'

# %%
b[-15:-3]
# Out:
# 'ME TO NARESH'

# %%
b[-19:-1]
# Out:
# 'ELCOME TO NARESH I'

# %%
b[:-19]
# Out:
# 'HELLO W'

# %%
b[-12:]
# Out:
# 'TO NARESH IT'

# %% [markdown]
# #step slicing

# %%
b[:]
# Out:
# 'HELLO WELCOME TO NARESH IT'

# %%
b[0:17:2]
# Out:
# 'HLOWLOET '

# %%
b[0:12:4]
# Out:
# 'HOL'

# %%
b[::4]
# Out:
# 'HOLE EI'

# %%
b[::2]
# Out:
# 'HLOWLOET AEHI'

# %%
b[::-1]
# Out:
# 'TI HSERAN OT EMOCLEW OLLEH'

# %%
b[::-6]
# Out:
# 'TR EE'

# %% [markdown]
# #TYPE CASTING

# %% [markdown]
# #int to other datatypes

# %%
int(190.34) # we can convert float to int
# Out:
# 190

# %%
int(True) # boolean to int possible
# Out:
# 1

# %%
int(False) # boolean to int possible
# Out:
# 0

# %%
int(1+12j) # comples to int notpossible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 int(1+12j) # comples to int notpossible
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10') # string to int possible
# Out:
# 10

# %%
int('Mousumi') # string-text to int possible
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 int('Mousumi') # string-text to int possible
#
# ValueError: invalid literal for int() with base 10: 'Mousumi'

# %% [markdown]
# #float to other datatypes

# %%
float(1210)  # int to float possible
# Out:
# 1210.0

# %%
float(True) # bool to float possible
# Out:
# 1.0

# %%
float(False) # bool to float possible
# Out:
# 0.0

# %%
float(1+2j) # complex to float possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('10') # string to float possible
# Out:
# 10.0

# %%
float('Mousumi') # string-text to float possible
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 float('Mousumi') # string-text to float possible
#
# ValueError: could not convert string to float: 'Mousumi'

# %% [markdown]
# #complex to other datatypes

# %%
complex(2)  # int to complex possible
# Out:
# (2+0j)

# %%
complex(3, 4)
# Out:
# (3+4j)

# %%
complex(3,4,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 complex(3,4,5)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2.3)  # float to complex possible
# Out:
# (2.3+0j)

# %%
complex(2.3, 4.5)
# Out:
# (2.3+4.5j)

# %%
complex(True) # bool to complex possible
# Out:
# (1+0j)

# %%
complex(False) # bool to complex possible
# Out:
# 0j

# %%
complex('10') # string to complex possible
# Out:
# (10+0j)

# %%
complex('10', '20') #for string only one argument can be taken not 2 string arguments
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 complex('10', '20') #for string only one argument can be taken not 2 string arguments
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex(10, '20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 complex(10, '20')
#
# TypeError: complex() second arg can't be a string

# %% [markdown]
#  #boolean to other datatypes (all non zero arguments are true in bolean)

# %%
bool(2) #int to bool possible
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(2.3) #float to bool possible
# Out:
# True

# %%
bool(1+2j) #complex to bool possible
# Out:
# True

# %%
bool('10') #string to bool possible
# Out:
# True

# %%
bool('ten') #string-text to bool possible
# Out:
# True

# %%
bool( )
# Out:
# False

# %%
bool(-2)
# Out:
# True

# %% [markdown]
#  #string to other datatypes

# %%
str(10) #int to string possible
# Out:
# '10'

# %%
str(10.4) #float to string possible
# Out:
# '10.4'

# %%
str(True) #bool to string possible
# Out:
# 'True'

# %%
str(1+2j) #complex to string possible
# Out:
# '(1+2j)'
