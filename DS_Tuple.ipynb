# %% [markdown]
# ## Tuples --> Immutable  (17-08-26)

# %%
t=()
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t1=(10,True,2.3,1+2j,"welcome")
t1
# Out:
# (10, True, 2.3, (1+2j), 'welcome')

# %%
t1.append(50) #tuple has no inbuilt function append
t1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 t1.append(50) #tuple has no inbuilt function append
#       2 t1
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t1
# Out:
# (10, True, 2.3, (1+2j), 'welcome')

# %%
t1[0]
# Out:
# 10

# %%
t1[0:4]
# Out:
# (10, True, 2.3, (1+2j))

# %%
t1[0]=100
t1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 t1[0]=100
#       2 t1
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1
# Out:
# (10, True, 2.3, (1+2j), 'welcome')

# %%
t1.count(10)
# Out:
# 1

# %%
t1.index(1+2j)
# Out:
# 3

# %%
t=(10,20,30)
t
# Out:
# (10, 20, 30)

# %%
t*3
# Out:
# (10, 20, 30, 10, 20, 30, 10, 20, 30)

# %% [markdown]
# ## Tuple practice

# %% [markdown]
# ## Tuple creation

# %%
tup1=() 
tup1
# Out:
# ()

# %%
tup2=(10,20,30)
tup2
# Out:
# (10, 20, 30)

# %%
tup3=(10.77,30.66,60.89) 
tup3
# Out:
# (10.77, 30.66, 60.89)

# %%
tup4=("one","two","three") 
tup4
# Out:
# ('one', 'two', 'three')

# %%
tup5=("Mousumi",25,(50,10),(150,90)) #Nested tuple
tup5
# Out:
# ('Mousumi', 25, (50, 10), (150, 90))

# %%
tup6=(100,"Mousumi",17.89) 
tup6
# Out:
# (100, 'Mousumi', 17.89)

# %%
tup7=("Mousumi",25,(50,10),(150,90) , {"Raj","Shyam"},(99,22,33)) 
tup7
# Out:
# ('Mousumi', 25, (50, 10), (150, 90), {'Raj', 'Shyam'}, (99, 22, 33))

# %%
len(tup7)
# Out:
# 6

# %% [markdown]
# ## Tuple Indexing

# %%
tup2[0]
# Out:
# 10

# %%
tup2[-1]
# Out:
# 30

# %%
tup7[3][0]
# Out:
# 150

# %%
tup4[0][0]
# Out:
# 'o'

# %%
tup5[-1]
# Out:
# (150, 90)

# %% [markdown]
# ## Tuple slicing

# %%
tup5
# Out:
# ('Mousumi', 25, (50, 10), (150, 90))

# %%
tup5[::-1]
# Out:
# ((150, 90), (50, 10), 25, 'Mousumi')

# %%
mytup=('one','two','three','four','five','six','seven','eight')
mytup
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytup[0:3]
# Out:
# ('one', 'two', 'three')

# %%
mytup[2:5]
# Out:
# ('three', 'four', 'five')

# %%
mytup[:3]
# Out:
# ('one', 'two', 'three')

# %%
mytup[:2]
# Out:
# ('one', 'two')

# %%
mytup[-3:]
# Out:
# ('six', 'seven', 'eight')

# %%
mytup[:-2]
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six')

# %%
mytup[-2:]
# Out:
# ('seven', 'eight')

# %%
mytup[-1]
# Out:
# 'eight'

# %%
mytup[:]
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytup[::-1]
# Out:
# ('eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one')

# %%
mytup[::-2]
# Out:
# ('eight', 'six', 'four', 'two')

# %%
mytup[::2]
# Out:
# ('one', 'three', 'five', 'seven')

# %%
mytup[::5]
# Out:
# ('one', 'six')

# %% [markdown]
# ## Remove and change items

# %%
mytup
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
del mytup[0] #Tuple are IMMUTABLE  which means we can't DELETE tuple items
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 del mytup[0] #Tupke are IMMUTABLE  which means we can't DELETE tuple items
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
mytup[0]=1 #Tuple are IMMUTABLE  which means we can't CHANGE tuple items
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 mytup[0]=1 #Tuple are IMMUTABLE  which means we can't CHANGE tuple items
#
# TypeError: 'tuple' object does not support item assignment

# %%
del mytup #Deleting emtire tuple object is possible
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 del mytup #Deleting emtire tuple object is possible
#
# NameError: name 'mytup' is not defined

# %%
mytup
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 mytup
#
# NameError: name 'mytup' is not defined

# %% [markdown]
# ## Index position

# %%
mytup=('one','two','three','four','five','six','seven','eight')
mytup
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytup.index('one')
# Out:
# 0

# %%
mytup.index('five')
# Out:
# 4

# %% [markdown]
# ## Sorting

# %%
mytup1=(43,67,99,12,6,90,67)
mytup1
# Out:
# (43, 67, 99, 12, 6, 90, 67)

# %%
sorted(mytup1) #Returns new sorted list and doesn't chnage original tuple
# Out:
# [6, 12, 43, 67, 67, 90, 99]

# %%
sorted(mytup1 , reverse=True) #Sort in desc order
# Out:
# [99, 90, 67, 67, 43, 12, 6]

# %% [markdown]
# ## Tuple Membership

# %%
mytup
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
'one' in mytup
# Out:
# True

# %%
'nine' in mytup
# Out:
# False

# %% [markdown]
# ## Loop through Tuple

# %%
mytup
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
for i in mytup:
    print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight

# %%
mytup1
# Out:
# (43, 67, 99, 12, 6, 90, 67)

# %%
for i in mytup1:
    print(i)
# Out:
# 43
# 67
# 99
# 12
# 6
# 90
# 67
