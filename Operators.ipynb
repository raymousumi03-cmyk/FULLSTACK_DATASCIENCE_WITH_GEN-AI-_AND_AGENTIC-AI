# %% [markdown]
# #Assignment operator(+=,-+,*=,/=,//=)

# %%
x=8
x += 2
x
# Out:
# 10

# %%
x -= 2
x
# Out:
# 8

# %%
x *= 2
x
# Out:
# 16

# %%
x //= 2
x
# Out:
# 8

# %%
x /= 2
x
# Out:
# 4.0

# %% [markdown]
# #Arithmetic operator(+,-,*,//,%,**)

# %%
x=8
y=10

# %%
x+y
# Out:
# 18

# %%
x-y
# Out:
# -2

# %%
x*y
# Out:
# 80

# %%
x//y
# Out:
# 0

# %%
x%y
# Out:
# 8

# %%
x**y
# Out:
# 1073741824

# %% [markdown]
# #unary operator(-)

# %%
x=9
x
# Out:
# 9

# %%
y=-(x)
y
# Out:
# -9

# %%
-x
# Out:
# -9

# %%
#Relational operator(<,>,<=,>=,!=,==)

# %%
a=9
b=8

a>b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
b=9

# %%
a==b
# Out:
# True

# %%
a!=b
# Out:
# False

# %%
a<=b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
#Logical operator(AND,OR,NOT)

# %%
a=5
b=4

# %%
a < 8 and b < 5
# Out:
# True

# %%
a < 8 and b > 5
# Out:
# False

# %%
a < 8 or b < 2
# Out:
# True

# %%
x = False
x
# Out:
# False

# %%
not x
# Out:
# True

# %%
y = True 
y
# Out:
# True

# %%
not y
# Out:
# False
