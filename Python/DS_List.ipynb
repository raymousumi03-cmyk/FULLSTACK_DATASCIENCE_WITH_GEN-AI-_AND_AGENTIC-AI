# %% [markdown]
# ## LIST -->  Mutable

# %%
l=[]
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %% [markdown]
# ## Append()

# %%
l.append(10) #append()--> add the value at the end of the list
l
# Out:
# [10]

# %%
len(l)
# Out:
# 1

# %%
l.append(10,20) #only one argument can be appended
l
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 l.append(10,20) #only one argument can be appended
#       2 l
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l1=[10]
l1
# Out:
# [10]

# %%
l1.append(20)
l1.append(30)
l1.append(40)
l1.append(50)
l1
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l1)
# Out:
# 5

# %%
l1.append(10)  #Duplicate is allowed
l1
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l2=[10,2.8,"mousumi",12+2j,True] #In list we can assign diffrent types of datatypes
l2
# Out:
# [10, 2.8, 'mousumi', (12+2j), True]

# %%
l2.append([1,2,3]) #nested list --> list inside another list is nested list
l2
# Out:
# [10, 2.8, 'mousumi', (12+2j), True, [1, 2, 3]]

# %% [markdown]
# ## copy()

# %%
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 2.8, 'mousumi', (12+2j), True, [1, 2, 3]]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l3=l1.copy() #to copy one list to another list
l3
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
print(l1)
print(l2)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 2.8, 'mousumi', (12+2j), True, [1, 2, 3]]
# [10, 20, 30, 40, 50, 10]

# %%
l1==l3
# Out:
# True

# %%
len(l1)==len(l3)
# Out:
# True

# %%
id(l1)==id(l3) #have same value but the id is not same
# Out:
# False

# %%
print(id(l1))  #both have diffrent id
print(id(l3))
# Out:
# 1232003825984
# 1232003097600

# %% [markdown]
# ## clear()

# %%
print(l1)
print(l2)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 2.8, 'mousumi', (12+2j), True, [1, 2, 3]]
# [10, 20, 30, 40, 50, 10]

# %%
l3.clear() #it clear all the value and gives empty list

# %%
print(l1)
print(l2)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 2.8, 'mousumi', (12+2j), True, [1, 2, 3]]
# []

# %%
del l3 #to delete any variable we use delete

# %%
l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 l3
#
# NameError: name 'l3' is not defined

# %%
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 2.8, 'mousumi', (12+2j), True, [1, 2, 3]]

# %% [markdown]
# ## count()

# %%
l1.count(20) #count the occurancces of value
# Out:
# 1

# %%
l1.count(10)
# Out:
# 2

# %% [markdown]
# ## extend()

# %%
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 2.8, 'mousumi', (12+2j), True, [1, 2, 3]]

# %%
l1.extend(l2) #we can merge the list
l1
# Out:
# [10, 20, 30, 40, 50, 10, 10, 2.8, 'mousumi', (12+2j), True, [1, 2, 3]]

# %%
print(len(l1))
print(len(l2))
# Out:
# 12
# 6

# %% [markdown]
# ## index()

# %%
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10, 10, 2.8, 'mousumi', (12+2j), True, [1, 2, 3]]
# [10, 2.8, 'mousumi', (12+2j), True, [1, 2, 3]]

# %%
l1.index(20) #indexing is allowed in list
# Out:
# 1

# %%
l2.index(12+2j)
# Out:
# 3

# %%
l2.index("mousumi")
# Out:
# 2

# %%
l2[:]
# Out:
# [10, 2.8, 'mousumi', (12+2j), True, [1, 2, 3]]

# %%
l2[5]
# Out:
# [1, 2, 3]

# %%
l2[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 l2[6]
#
# IndexError: list index out of range

# %%
l2[:3]
# Out:
# [10, 2.8, 'mousumi']

# %%
l2[3:]
# Out:
# [(12+2j), True, [1, 2, 3]]

# %%
l2
# Out:
# [10, 2.8, 'mousumi', (12+2j), True, [1, 2, 3]]

# %%
l2[0:5:2]
# Out:
# [10, 'mousumi', True]

# %%
l2[-3]
# Out:
# (12+2j)

# %%
l2[-3:]
# Out:
# [(12+2j), True, [1, 2, 3]]

# %%
l2[::-1]
# Out:
# [[1, 2, 3], True, (12+2j), 'mousumi', 2.8, 10]

# %%
l2[::-2]
# Out:
# [[1, 2, 3], (12+2j), 2.8]

# %%
l2
# Out:
# [10, 2.8, 'mousumi', (12+2j), True, [1, 2, 3]]

# %%
l2[2]
# Out:
# 'mousumi'

# %%
print(l2[2][0]) #nested index--> index within another index
print(l2[2][1])
print(l2[2][2])
print(l2[2][3])
print(l2[2][4])
print(l2[2][5])
print(l2[2][6])
print(l2[2][7])
# Out:
# m
# o
# u
# s
# u
# m
# i
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[76], line 8
#       6 print(l2[2][5])
#       7 print(l2[2][6])
# ----> 8 print(l2[2][7])
#
# IndexError: string index out of range

# %%
l2
# Out:
# [10, 2.8, 'mousumi', (12+2j), True, [1, 2, 3]]

# %%
l2[0]=100  #mutable-->changable (list is mutable)
l2
# Out:
# [100, 2.8, 'mousumi', (12+2j), True, [1, 2, 3]]

# %%
l2
# Out:
# [100, 2.8, 'mousumi', (12+2j), True, [1, 2, 3]]

# %% [markdown]
# ## 17-08-26

# %% [markdown]
# ## insert

# %%
l3=[10,20,30]
l3
# Out:
# [10, 20, 30]

# %%
l3[0]=100
l3
# Out:
# [100, 20, 30]

# %%
l3.insert(2,25)
l3
# Out:
# [100, 20, 25, 30]

# %%
l3.insert(2,[1,2,3])
l3
# Out:
# [100, 20, [1, 2, 3], 25, 30]

# %% [markdown]
# ## pop() -->remove value based on indexing

# %%
l3.pop()
# Out:
# 30

# %%
l3
# Out:
# [100, 20, [1, 2, 3], 25]

# %%
l2
# Out:
# [100, 2.8, 'mousumi', (12+2j), True, [1, 2, 3]]

# %%
l2.pop()
# Out:
# [1, 2, 3]

# %%
l2.pop(-2)
# Out:
# (12+2j)

# %%
l2
# Out:
# [100, 2.8, 'mousumi', True]

# %% [markdown]
# ## remove() --> direct remove value not  indexing

# %%
l2.remove(2.8)

# %%
l2
# Out:
# [100, 'mousumi']

# %% [markdown]
# ## reverse()

# %%
print(l1)
print(l2)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10, 10, 2.8, 'mousumi', (12+2j), True, [1, 2, 3]]
# [100, 'mousumi']
# [100, 20, [1, 2, 3], 25]

# %%
l2.reverse()
l2
# Out:
# ['mousumi', 100]

# %%
l3[::-1]
# Out:
# [25, [1, 2, 3], 20, 100]

# %% [markdown]
# ## sort() --> bydefault it gives ascending sorting
# ##         --> it only works when we have similar datatype

# %%
l4=[3,300,23,200,1000,10]
l4
# Out:
# [3, 300, 23, 200, 1000, 10]

# %%
l4.sort() #bydefault it is reverse=False i.e, descending sort
l4
# Out:
# [3, 10, 23, 200, 300, 1000]

# %%
l4.sort( reverse=True)
l4
# Out:
# [1000, 300, 200, 23, 10, 3]

# %%
l3.sort()
l3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 l3.sort()
#       2 l3
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %% [markdown]
# ## list membership

# %%
l4
# Out:
# [1000, 300, 200, 23, 10, 3]

# %%
10 in l4
# Out:
# True

# %%
100 in l4
# Out:
# False

# %% [markdown]
# ## All and Any --> in list if we have 0 value ALL will print false , else true

# %%
l4
# Out:
# [1000, 300, 200, 23, 10, 3]

# %%
all(l4)
# Out:
# True

# %%
any(l4)
# Out:
# True

# %%
l4.append(0)
l4
# Out:
# [1000, 300, 200, 23, 10, 3, 0]

# %%
all(l4)
# Out:
# False

# %%
any(l4)
# Out:
# True

# %% [markdown]
# ## PRACTICE (17-08-26)

# %% [markdown]
# ## strip -->Removes whitespace
# ## lstrip --> Removes whitespace from left side only
# ## rstrip --> Removes whitespace from right side only

# %%
txt = "   abc def ghi   " 
 
txt.lstrip()
# Out:
# 'abc def ghi   '

# %%
txt = "  abc def ghi  " 
txt.strip()
# Out:
# 'abc def ghi'

# %%
txt = "   abc def ghi   " 
 
txt.rstrip()
# Out:
# '   abc def ghi'

# %% [markdown]
# ## escape character ( \ )

# %%
#Using double quotes in the string is not allowed. 
mystr = "My favourite TV Series is "Game of Thrones""
# Out:
#   Cell In[8], line 2
#     mystr = "My favourite TV Series is "Game of Thrones""
#                                         ^
# SyntaxError: invalid syntax

# %%
mystr = "My favourite series is \"Game of Thrones\"" 
print(mystr)
# Out:
# My favourite series is "Game of Thrones"

# %% [markdown]
# ## List question practice

# %%
list1 = [] # Empty List

# %%
print(type(list1))
# Out:
# <class 'list'>

# %%
list2 = [10,30,60] # List of integers numbers

# %%
list3 = [10.77,30.66,60.89] # List of float numbers

# %%
list4 = ['one','two' , "three"] # List of strings

# %%
list5 = ['Asif', 25 ,[50, 100],[150, 90]] # Nested Lists

# %%
list6 = [100, 'Asif', 17.765] # List of mixed data types

# %%
list7 = ['Asif', 25 ,[50, 100],[150, 90] , {'John' , 'David'}]

# %%
len(list6) #Length of list
# Out:
# 3

# %% [markdown]
# ## list indexing

# %%
list2[0] # Retreive first element of the list
# Out:
# 10

# %%
list4[0] # Retreive first element of the list
# Out:
# 'one'

# %%
list4[0][0] # Nested indexing - Access the first character of the first list element
# Out:
# 'o'

# %%
list4[-1] # Last item of the list
# Out:
# 'three'

# %%
list5[-1] # Last item of the list
# Out:
# [150, 90]

# %% [markdown]
# ## list slicing

# %%
mylist = ['one' , 'two' , 'three' , 'four' , 'five' , 'six' , 'seven' , 'eight']

# %%
mylist[0:3] # Return all items from 0th to 3rd index location excluding the item (3-1=2) upto 2nd index
# Out:
# ['one', 'two', 'three']

# %%
mylist[2:5] # List all items from 2nd to 5th index location excluding the item a
# Out:
# ['three', 'four', 'five']

# %%
mylist[:3] # Return first three items
# Out:
# ['one', 'two', 'three']

# %%
mylist[:2] # Return first two items
# Out:
# ['one', 'two']

# %%
mylist[-3:] # Return last three items
# Out:
# ['six', 'seven', 'eight']

# %%
mylist[-2:] # Return last two items
# Out:
# ['seven', 'eight']

# %%
mylist[-1] # Return last item of the list
# Out:
# 'eight'

# %%
mylist[:] # Return whole list
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# ## Add,remove and change items

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist.append('nine') # Add an item to the end of the list 
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist.insert(9,'ten') # Add item at index location 9 
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
mylist.insert(1,'ONE') # Add item at index location 1 
mylist
# Out:
# ['one',
#  'ONE',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten']

# %%
mylist.remove('ONE') # Remove item "ONE" 
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
mylist.pop() # Remove last item of the list 
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist.pop(8) # Remove item at index location 8 
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
del mylist[7] # Remove item at index location 7 
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven']

# %%
#changing value  of the string

mylist[0] = 1 
mylist[1] = 2 
mylist[2] = 3 
mylist
# Out:
# [1, 2, 3, 'four', 'five', 'six', 'seven']

# %%
mylist.clear() # Empty List / Delete all items in the list 
mylist
# Out:
# []

# %%
del mylist # Delete the whole list 
mylist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 del mylist # Delete the whole list
# ----> 2 mylist
#
# NameError: name 'mylist' is not defined

# %% [markdown]
# ## copy list

# %%
mylist = ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist1 = mylist # Create a new reference "mylist1"  (= --> same box)

# %%
id(mylist) , id(mylist1) # The address of both mylist & mylist1 will be the same
# Out:
# (2113068301632, 2113068301632)

# %%
mylist2 = mylist.copy() # Create a copy of the list (.copy -> new box)

# %%
id(mylist2) # The address of mylist2 will be different from mylist because mylist
# Out:
# 2113074732864

# %%
mylist[0] = 1

# %%
mylist
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist1 # mylist1 will be also impacted as it is pointing to the same list
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist2 # Copy of list won't be impacted due to changes made on the original list because (they are stored as diffrent list object)
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %% [markdown]
# ## join list

# %%
list1 = ['one', 'two', 'three', 'four'] 
list2 = ['five', 'six', 'seven', 'eight']

# %%
list3 = list1 + list2 # Join two lists by '+' operator 
list3
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.extend(list2) #Append list2 with list1 
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# ## list membership

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
'one' in list1 # Check if 'one' exist in the list
# Out:
# True

# %%
'ten' in list1 # Check if 'ten' exist in the list
# Out:
# False

# %%
if 'three' in list1: # Check if 'three' exist in the list 
  print('Three is present in the list') 
else: 
  print('Three is not present in the list')
# Out:
# Three is present in the list

# %%
if 'eleven' in list1: # Check if 'eleven' exist in the list 
  print('eleven is present in the list') 
else: 
  print('eleven is not present in the list')
# Out:
# eleven is not present in the list

# %% [markdown]
# ## Reverse and sort list

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.reverse() # Reverse the list 
list1
# Out:
# ['eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one']

# %%
list1 = list1[::-1] # Reverse the list 
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist3 = [9,5,2,99,12,88,34] 
mylist3.sort() # Sort list in ascending order 
mylist3
# Out:
# [2, 5, 9, 12, 34, 88, 99]

# %%
mylist3 = [9,5,2,99,12,88,34] 
mylist3.sort(reverse=True) # Sort list in descending order 
mylist3
# Out:
# [99, 88, 34, 12, 9, 5, 2]

# %%
mylist4 = [88,65,33,21,11,98] 
sorted(mylist4) # Returns a new sorted list and doesn't change original list
# Out:
# [11, 21, 33, 65, 88, 98]

# %%
mylist4
# Out:
# [88, 65, 33, 21, 11, 98]

# %% [markdown]
# ## count

# %%
list10 =['one', 'two', 'three', 'four', 'one', 'one', 'two', 'three']

# %%
list10.count('one') # Number of times item "one" occurred in the list.
# Out:
# 3

# %%
list10.count('two') # Occurence of item 'two' in the list
# Out:
# 2

# %%
list10.count('four') #Occurence of item 'four' in the list
# Out:
# 1

# %% [markdown]
# ## All / Any
#
# # The all() method returns:
#
# # True - If all elements in a list are true
# # False - If any element in a list is false
#
# # The any() function returns True if any element in the list is True. If not, any() returns False.

# %%
L1 = [1,2,3,4,0]

# %%
all(L1) # Will Return false as one value is false (Value 0)
# Out:
# False

# %%
any(L1) # Will Return True as we have items in the list with True value
# Out:
# True

# %%
L2 = [1,2,3,4,True,False]

# %%
all(L2) # Returns false as one value is false
# Out:
# False

# %%
any(L2) # Will Return True as we have items in the list with True value
# Out:
# True

# %%
L3 = [1,2,3,True]

# %%
all(L3) # Will return True as all items in the list are True
# Out:
# True

# %%
any(L3)
# Out:
# True
